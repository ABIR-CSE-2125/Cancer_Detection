# %% [markdown]
# # Insightts Drawn from the models

# %% [markdown]
# ## Pass 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load Result  Dataset

# %%
df = pd.read_csv("../notebook/results/results.csv")

# %%
df.head(5)

# %%
df.tail(5)

# %%
df.columns

# %%
df["model"].unique()

# %% [markdown]
# ### Mean Training Accuracy v/s test size
# ### Mean Testing Accuracy v/s test size
# #### for different crossvalidation folds

# %%
Logistic_model_results = df[df["model"] == "Logistic Regression"]
DTree_model_results = df[df["model"] == "Decision Tree"]
Naive_Bayes_model_results = df[df["model"] == "Naive Bayes"]

# %%
sns.pairplot(data=df,palette="Set2");

# %%
plt.figure(figsize=(12,9))
sns.lineplot(data=df,x=df.index,y=df["Training Mean Accuracy"]*10,hue="No of Cross Validations",palette="Spectral")

# %%
plt.figure(figsize=(12,9))
sns.lineplot(data=df,x=df.index,y=df["Testing Mean Accuracy"]*100,palette="pastel")

# %%
df_sorted_by_test_size=df.sort_values(by="Test Size").reset_index(drop=True)

# %%
df_sorted_by_test_size

# %%
df_sorted_by_test_size[df_sorted_by_test_size["model"] == "Logistic Regression"]["Training Mean Accuracy"].shape

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Training Mean Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Training Mean Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Training Mean Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
plt.title("Logistic Regression")
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Training Mean Accuracy",hue="No of Cross Validations",palette="Set1")
plt.subplot(132)
plt.title("Decision Tree")
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Training Mean Accuracy",hue="No of Cross Validations",palette="Set2")
plt.subplot(133)
plt.title("Naive Bayes")
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Training Mean Accuracy",hue="No of Cross Validations",palette="Set3")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Testing Mean Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Testing Mean Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Testing Mean Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
plt.title("Logistic Regression")
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Testing Mean Accuracy",hue="No of Cross Validations",palette="Set1")
plt.subplot(132)
plt.title("Decision Tree")
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Testing Mean Accuracy",hue="No of Cross Validations",palette="Set2")
plt.subplot(133)
plt.title("Naive Bayes")
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Testing Mean Accuracy",hue="No of Cross Validations",palette="Set3")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Training Max Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Training Max Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Training Max Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
plt.title("Logistic Regression")
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Training Max Accuracy",hue="No of Cross Validations",palette="Set1")
plt.subplot(132)
plt.title("Decision Tree")
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Training Max Accuracy",hue="No of Cross Validations",palette="Set2")
plt.subplot(133)
plt.title("Naive Bayes")
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Training Max Accuracy",hue="No of Cross Validations",palette="Set3")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Testing Max Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Testing Max Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Testing Max Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
plt.title("Logistic Regression")
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Testing Max Accuracy",hue="No of Cross Validations",palette="Set1")
plt.subplot(132)
plt.title("Decision Tree")
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Testing Max Accuracy",hue="No of Cross Validations",palette="Set2")
plt.subplot(133)
plt.title("Naive Bayes")
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Testing Max Accuracy",hue="No of Cross Validations",palette="Set3")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Training Standard Deviation",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Training Standard Deviation",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Training Standard Deviation",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
plt.title("Logistic Regression")
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Training Standard Deviation",hue="No of Cross Validations",palette="Set1")
plt.subplot(132)
plt.title("Decision Tree")
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Training Standard Deviation",hue="No of Cross Validations",palette="Set2")
plt.subplot(133)
plt.title("Naive Bayes")
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Training Standard Deviation",hue="No of Cross Validations",palette="Set3")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Testing Standard Deviation",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Testing Standard Deviation",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Testing Standard Deviation",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
plt.title("Logistic Regression")
sns.lineplot(data=Logistic_model_results,x = "Test Size",y="Testing Standard Deviation",hue="No of Cross Validations",palette="Set1")
plt.subplot(132)
plt.title("Decision Tree")
sns.lineplot(data=DTree_model_results,x = "Test Size",y="Testing Standard Deviation",hue="No of Cross Validations",palette="Set2")
plt.subplot(133)
plt.title("Naive Bayes")
sns.lineplot(data=Naive_Bayes_model_results,x = "Test Size",y="Testing Standard Deviation",hue="No of Cross Validations",palette="Set3")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Training Mean Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Training Mean Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Training Mean Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Training Mean Accuracy",hue="Test Size",palette="Set1")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Training Mean Accuracy",hue="Test Size",palette="Set2")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Training Mean Accuracy",hue="Test Size",palette="Set3")
plt.title("Naive Bayes")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Testing Mean Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Testing Mean Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Testing Mean Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Testing Mean Accuracy",hue="Test Size",palette="Set1")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Testing Mean Accuracy",hue="Test Size",palette="Set2")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Testing Mean Accuracy",hue="Test Size",palette="Set3")
plt.title("Naive Bayes")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Training Max Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Training Max Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Training Max Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Training Max Accuracy",hue="Test Size",palette="Set1")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Training Max Accuracy",hue="Test Size",palette="Set2")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Training Max Accuracy",hue="Test Size",palette="Set3")
plt.title("Naive Bayes")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Testing Max Accuracy",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Testing Max Accuracy",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Testing Max Accuracy",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Testing Max Accuracy",hue="Test Size",palette="Set1")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Testing Max Accuracy",hue="Test Size",palette="Set2")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Testing Max Accuracy",hue="Test Size",palette="Set3")
plt.title("Naive Bayes")

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Training Standard Deviation",color="red")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Training Standard Deviation",color="blue")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Training Standard Deviation",color="green")
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
plt.figure(figsize=(24,8))
plt.subplot(131)
sns.lineplot(data=Logistic_model_results,x = "No of Cross Validations",y="Training Standard Deviation",hue="Test Size",palette="Set1")
plt.title("Logistic Regression")
plt.subplot(132)
sns.lineplot(data=DTree_model_results,x = "No of Cross Validations",y="Training Standard Deviation",hue="Test Size",palette="Set2")
plt.title("Decision Tree")
plt.subplot(133)
sns.lineplot(data=Naive_Bayes_model_results,x = "No of Cross Validations",y="Training Standard Deviation",hue="Test Size",palette="Set3")
plt.title("Naive Bayes")
